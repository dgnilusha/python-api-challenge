# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
from scipy.stats import linregress
# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
#weather_api_key

# %%
#save config info
#url = "https://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
units = "metric"

#build query url
#query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
#print(query_url)

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 585

# %%
print(cities)
# Out:
# ['fort mcmurray', 'olinda', 'college', 'wa', 'ancud', 'bredasdorp', 'port-aux-francais', 'bang saphan', 'nikolayevsk-on-amure', 'avarua', 'gadzhiyevo', 'yellowknife', 'blackmans bay', 'adamstown', 'port alfred', 'port elizabeth', 'puerto leguizamo', 'james island', 'talnakh', 'montagu', 'along', 'port mathurin', 'cidreira', 'nainpur', 'pacific grove', "nuku'alofa", 'ushuaia', 'am djarass', 'waitangi', 'puerto san carlos', 'papatowai', 'bengkulu', 'januaria', 'coquimbo', 'san antonio de pale', 'petropavlovsk-kamchatsky', 'iqaluit', 'enewetak', 'stanley', 'el granada', 'jamestown', 'udachny', 'puerto ayora', 'qaqortoq', 'afaahiti', 'dudinka', 'kirakira', 'yanchep', 'muntok', 'aileu', 'edinburgh of the seven seas', 'kodiak', 'whitehorse', 'christchurch', 'an nuhud', 'targu carbunesti', 'nema', 'hasaki', 'dryden', 'constantia', 'anadyr', 'alpine', 'fonte boa', 'cargados carajos', 'albany', 'asau', 'arraial do cabo', 'aasiaat', 'challapata', 'remire-montjoly', 'mundybash', 'chonchi', 'vorgashor', 'la passe', 'taiohae', 'namibe', 'forster', 'pisco', 'fortuna', 'ingeniero jacobacci', 'tranovaho', 'al mutayrifi', 'ascension', 'taco pozo', 'margaret river', 'achinsk', "lebyazh'ye", 'waterloo', 'pedernales', 'ar rutbah', 'bethel', 'ixtapa', "'ohonua", 'la gi', 'inekar', 'taulaga', 'praya', 'corumba', 'nova sintra', 'porbandar', 'ribeira grande', 'muang phon-hong', 'punta arenas', 'tadine', 'west island', 'port lincoln', 'zhalantun', 'kerikeri', 'sonsorol village', 'uliastay', 'grytviken', 'shiwan', 'kindu', 'ampanihy', 'padam', 'badger', 'naze', 'fort bragg', 'utrik', 'pizarro', 'puerto natales', 'antofagasta', 'mgandu', 'iskateley', 'mata-utu', 'romanovo', 'crane', 'mejit', 'labytnangi', 'clearwater', 'inarajan village', 'kavieng', 'petite riviere', 'tidjikja', 'vilyuchinsk', 'invercargill', 'ridgecrest', 'saipan', 'bikaner', "port saint john's", 'pibor', 'bilibino', 'jasidih', 'qui nhon', 'ilulissat', 'deir ez-zor', 'sao jose da coroa grande', 'awjilah', 'sanandaj', 'vingt cinq', 'falmouth', 'uporovo', 'broken hill', 'dispur', 'bathurst city centre', 'touros', 'hami', 'hamilton', 'grand gaube', 'lompoc', 'klyuchi', 'mandalgovi', 'susuman', 'rengasdengklok', 'mangrol', 'walcz', 'banda aceh', 'maine soroa', 'hobyo', 'lebu', 'circleville', 'shumikha', 'polyarnyy', 'arroyo', 'camarinas', 'necochea', 'roma', 'olonkinbyen', 'prince rupert', 'flying fish cove', 'queenstown', 'tuy hoa', 'fuvahmulah', 'besuki', 'belyy yar', 'waslala', 'kirensk', 'lazaro cardenas', 'vernon', 'mariental', 'nizhneangarsk', 'isafjordur', 'vila velha', 'lago da pedra', 'bukama', "hayma'", 'woodstock', 'sirte', 'argostolion', 'borogontsy', 'fuxin', 'lihue', 'magadan', 'iwaki', 'yauya', 'yangcun', 'georgetown', 'general jose de san martin', 'praia da vitoria', 'devinuwara', 'takaungu', 'pacasmayo', 'lethem', 'bogalusa', 'lerwick', 'handan', 'saint-pierre', 'kabinda', 'bargara', 'isla mujeres', 'atafu village', 'grand falls-windsor', 'ad dawadimi', 'rongelap', 'paradise valley', 'vadso', 'trincomalee', 'meadow lake', 'tura', 'sitka', 'oualidia', 'salekhard', 'axim', 'shiqian', 'ngambe', 'al ghayzah', 'wailua homesteads', 'pesaro', 'wichian buri', 'raduzhnyy', 'san patricio', 'thompson', 'xilin hot', 'mugia', 'alice springs', 'reggane', 'balcarce', 'pinhao', 'dalandzadgad', 'hermanus', 'gereida', 'hassi messaoud', 'papao', 'daru', 'hawaiian paradise park', 'abbeville', 'birzebbuga', 'santa elena de uairen', 'sarukhan', 'yanam', 'tingi', 'saint-philippe', 'malumfashi', 'yuyao', 'carnarvon', 'akureyri', 'nova vicosa', 'gudari', 'jamaame', 'miles city', 'nemuro', 'kavaratti', 'tazacorte', 'elko', 'boden', 'keflavik', 'pama', 'newport', 'mostaganem', 'mount gambier', 'sungai penuh', 'dunedin', 'sandviken', 'ras gharib', "kem'", 'ust-nera', 'peterborough', 'sao vicente', 'bikenibeu village', 'dakhla', 'launceston', 'mhamid', 'tarawa', 'aras-asan', 'kingston', 'masterton', 'gulf shores', 'colonia', 'ciudad lazaro cardenas', 'fandrandava', 'crucecita', 'chadan', 'zemio', 'sav ...

# %%
response = requests.get(query_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 2
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -45.5882,
#         "lon": -69.07
#     },
#     "dt": 1684704801,
#     "id": 3835710,
#     "main": {
#         "feels_like": 2.75,
#         "grnd_level": 968,
#         "humidity": 41,
#         "pressure": 1001,
#         "sea_level": 1001,
#         "temp": 8.06,
#         "temp_max": 8.06,
#         "temp_min": 8.06
#     },
#     "name": "Sarmiento",
#     "sys": {
#         "country": "AR",
#         "sunrise": 1684670137,
#         "sunset": 1684703423
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 266,
#         "gust": 20.3,
#         "speed": 14.55
#     }
# }

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
# url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
 # Parse the JSON and retrieve data
        response = requests.get(query_url)
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | fort mcmurray
# Processing Record 2 of Set 1 | olinda
# Processing Record 3 of Set 1 | college
# Processing Record 4 of Set 1 | wa
# City not found. Skipping...
# Processing Record 5 of Set 1 | ancud
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | bang saphan
# Processing Record 9 of Set 1 | nikolayevsk-on-amure
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | gadzhiyevo
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | blackmans bay
# Processing Record 14 of Set 1 | adamstown
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | puerto leguizamo
# Processing Record 18 of Set 1 | james island
# City not found. Skipping...
# Processing Record 19 of Set 1 | talnakh
# Processing Record 20 of Set 1 | montagu
# Processing Record 21 of Set 1 | along
# Processing Record 22 of Set 1 | port mathurin
# Processing Record 23 of Set 1 | cidreira
# Processing Record 24 of Set 1 | nainpur
# Processing Record 25 of Set 1 | pacific grove
# Processing Record 26 of Set 1 | nuku'alofa
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | am djarass
# City not found. Skipping...
# Processing Record 29 of Set 1 | waitangi
# Processing Record 30 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 31 of Set 1 | papatowai
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | januaria
# Processing Record 34 of Set 1 | coquimbo
# Processing Record 35 of Set 1 | san antonio de pale
# Processing Record 36 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 37 of Set 1 | iqaluit
# Processing Record 38 of Set 1 | enewetak
# Processing Record 39 of Set 1 | stanley
# Processing Record 40 of Set 1 | el granada
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | udachny
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | qaqortoq
# Processing Record 45 of Set 1 | afaahiti
# Processing Record 46 of Set 1 | dudinka
# Processing Record 47 of Set 1 | kirakira
# Processing Record 48 of Set 1 | yanchep
# Processing Record 49 of Set 1 | muntok
# Processing Record 50 of Set 1 | aileu
# Processing Record 0 of Set 2 | edinburgh of the seven seas
# Processing Record 1 of Set 2 | kodiak
# Processing Record 2 of Set 2 | whitehorse
# Processing Record 3 of Set 2 | christchurch
# Processing Record 4 of Set 2 | an nuhud
# Processing Record 5 of Set 2 | targu carbunesti
# Processing Record 6 of Set 2 | nema
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | dryden
# Processing Record 9 of Set 2 | constantia
# Processing Record 10 of Set 2 | anadyr
# Processing Record 11 of Set 2 | alpine
# Processing Record 12 of Set 2 | fonte boa
# Processing Record 13 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | asau
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | aasiaat
# Processing Record 18 of Set 2 | challapata
# Processing Record 19 of Set 2 | remire-montjoly
# Processing Record 20 of Set 2 | mundybash
# Processing Record 21 of Set 2 | chonchi
# Processing Record 22 of Set 2 | vorgashor
# Processing Record 23 of Set 2 | la passe
# Processing Record 24 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 2 | namibe
# Processing Record 26 of Set 2 | forster
# Processing Record 27 of Set 2 | pisco
# Processing Record 28 of Set 2 | fortuna
# Processing Record 29 of Set 2 | ingeniero jacobacci
# Processing Record 30 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 31 of Set 2 | al mutayrifi
# Processing Record 32 of Set 2 | ascension
# Processing Record 33 of Set 2 | taco pozo
# Processing Record 34 of Set 2 | margaret river
# Processing Record 35 of Set 2 | achinsk
# Processing Record 36 of Set 2 | lebyazh'ye
# Processing Record 37 of Set 2 | waterloo
# Processing Record 38 of Set 2 | pedernales
# Processing Record 39 of Set 2 | ar rutbah
# Processing Record 40 of Set 2 | bethel
# Processing Record 41 of Set 2 | ixtapa
# Processing Record 42 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 43 of Set 2 | la gi
# Processing Record 44 of Set 2 | inekar
# City not found. Skipping...
# Processing Record 45 of Set 2 | taulaga
# Processing Record 46 of Set 2 | praya
# Processing Record 47 of Set 2 | corumba
# Processing Record 48 of Set 2 | nova sintra
# Processing Record 49 of Set 2 | porbandar
# Processing Record 0 of Set 3 | ribeira grande
# Processing Record 1 of Set 3 | muang phon-hong
# Processing Record 2 of Set 3 | punta arenas
# Processing Record 3 of Set 3 | tadine
# Processing Record 4 of Set 3 | west island
# Processing Record 5 of Set 3 | port lincoln
# Processing Record 6 of Set 3 | zhalantun
# Processing Record 7 of Set 3 | kerikeri
# Processing Record 8 of Set 3 | sonsorol village
# City not found. Skipping...
# Processing Record 9 of Set 3 | uliastay
# Processing Record 10 of Set 3 | grytviken
# Processing Record 11 of Set 3 | shiwan
# Processing Record 12 of Set 3 | kindu
# Processing Record 13 of Set 3 | ampanihy
# Processing Record 14 of Set 3 | padam
# City not found. Skipping...
# Processing Record 15 of Set 3 | badger
# Processing Record 16 of Set 3 | naze
# Processing Record 17 of Set 3 | fort bragg
# Processing Record 18 of Set 3 | utrik
# Processing Record 19 of Set 3 | pizarro
# Processing Record 20 of Set 3 | puerto natales
# Processing Record 21 of Set 3 | antofagasta
# Processing Record 22 of Set 3 | mgandu
# Processing Record 23 of Set 3 | iskateley
# Processing Record 24 of Set 3 | mata-utu
# Processing Record 25 of Set 3 | romanovo
# Processing Record 26 of Set 3 | crane
# Processing Record 27 of Set 3 | mejit
# Processing Record 28 of Set 3 | labytnangi
# Processing Record 29 of Set 3 | clearwater
# Processing Record 30 of Set 3 | inarajan village
# Processing Record 31 of Set 3 | kavieng
# Processing Record 32 of Set 3 | petite riviere
# Processing Record 33 of Set 3 | tidjikja
# Processing Record 34 of Set 3 | vilyuchinsk
# Processing Record 35 of Set 3 | invercargill
# Processing Record 36 of Set 3 | ridgecrest
# Processing Record 37 of Set 3 | saipan
# Processing Record 38 of Set 3 | bikaner
# Processing Record 39 of Set 3 | port saint john's
# Processing Record 40 of Set 3 | pibor
# City not found. Skipping...
# Processing Record 41 of Set 3 | bilibino
# Processing Record 42 of Set 3 | jasidih
# Processing Record 43 of Set 3 | qui nhon
# Processing Record 44 of Set 3 | ilulissat
# Processing Record 45 of Set 3 | deir ez-zor
# Processing Record 46 of Set 3 | sao jose da coroa grande
# Processing Record 47 of Set 3 | awjilah
# Processing Record 48 of Set 3 | sanandaj
# Processing Record 49 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 0 of Set 4 | falmouth
# Processing Record 1 of Set 4 | uporovo
# Processing Record 2 of Set 4 | broken hill
# Processing Record 3 of Set 4 | dispur
# Processing Record 4 of Set 4 | bathurst city centre
# City not found. Skipping...
# Processing Record 5 of Set 4 | touros
# Processing Record 6 of Set 4 | hami
# Processing Record 7 of Set 4 | hamilton
# Processing Record 8 of Set 4 | grand gaube
# Processing Record 9 of Set 4 | lompoc
# Processing Record 10 of Set 4 | klyuchi
# Processing Record 11 of Set 4 | mandalgovi
# Processing Record 12 of Set 4 | susuman
# Processing Record 13 of Set 4 | rengasdengklok
# Processing Record 14 of Set 4 | mangrol
# Processing Record 15 of Set 4 | walcz
# Processing Record 16 of Set 4 | banda aceh
# Processing Record 17 of Set 4 | maine soroa
# Processing Record 18 of Set 4 | hobyo
# Processing Record 19 of Set 4 | lebu
# Processing Record 20 of Set 4 | circleville
# Processing Record 21 of Set 4 | shumikha
# Processing Record 22 of Set 4 | polyarnyy
# Processing Record 23 of Set 4 | arroyo
# Processing Record 24 of Set 4 | camarinas
# Processing Record 25 of Set 4 | necochea
# Processing Record 26 of Set 4 | roma
# Processing Record 27 of Set 4 | olonkinbyen
# Processing Record 28 of Set 4 | prince rupert
# Processing Record 29 of Set 4 | flying fish cove
# Processing Record 30 of Set 4 | queenstown
# Processing Record 31 of Set 4 | tuy hoa
# Processing Record 32 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 33 of Set 4 | besuki
# Processing Record 34 of Set 4 | belyy yar
# Processing Record 35 of Set 4 | waslala
# Processing Record 36 of Set 4 | kirensk
# Processing Record 37 of Set 4 | lazaro cardenas
# Processing Record 38 of Set 4 | vernon
# Processing Record 39 of Set 4 | mariental
# Processing Record 40 of Set 4 | nizhneangarsk
# Processing Record 41 of Set 4 | isafjordur
# Processing Record 42 of Set 4 | vila velha
# Processing Record 43 of Set 4 | lago da pedra
# Processing Record 44 of Set 4 | bukama
# Processing Record 45 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 46 of Set 4 | woodstock
# Processing Record 47 of Set 4 | sirte
# Processing Record 48 of Set 4 | argostolion
# Processing Record 49 of Set 4 | borogontsy
# Processing Record 0 of Set 5 | fuxin
# Processing Record 1 of Set 5 | lihue
# Processing Record 2 of Set 5 | magadan
# Processing Record 3 of Set 5 | iwaki
# Processing Record 4 of Set 5 | yauya
# Processing Record 5 of Set 5 | yangcun
# Processing Record 6 of Set 5 | georgetown
# Processing Record 7 of Set 5 | general jose de san martin
# Processing Record 8 of Set 5 | praia da vitoria
# Processing Record 9 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 10 of Set 5 | takaungu
# Processing Record 11 of Set 5 | pacasmayo
# Processing Record 12 of Set 5 | lethem
# Processing Record 13 of Set 5 | bogalusa
# Processing Record 14 of Set 5 | lerwick
# Processing Record 15 of Set 5 | handan
# Processing Record 16 of Set 5 | saint-pierre
# Processing Record 17 of Set 5 | kabinda
# Processing Record 18 of Set 5 | bargara
# City not found. Skipping...
# Processing Record 19 of Set 5 | isla mujeres
# Processing Record 20 of Set 5 | atafu village
# Processing Record 21 of Set 5 | grand falls-windsor
# Processing Record 22 of Set 5 | ad dawadimi
# Processing Record 23 of Set 5 | rongelap
# Processing Record 24 of Set 5 | paradise valley
# Processing Record 25 of Set 5 | vadso
# Processing Record 26 of Set 5 | trincomalee
# Processing Record 27 of Set 5 | meadow lake
# Processing Record 28 of Set 5 | tura
# Processing Record 29 of Set 5 | sitka
# Processing Record 30 of Set 5 | oualidia
# City not found. Skipping...
# Processing Record 31 of Set 5 | salekhard
# Processing Record 32 of Set 5 | axim
# Processing Record 33 of Set 5 | shiqian
# Processing Record 34 of Set 5 | ngambe
# Processing Record 35 of Set 5 | al ghayzah
# Processing Record 36 of Set 5 | wailua homesteads
# Processing Record 37 of Set 5 | pesaro
# Processing Record 38 of Set 5 | wichian buri
# Processing Record 39 of Set 5 | raduzhnyy
# Processing Record 40 of Set 5 | san patricio
# Processing Record 41 of Set 5 | thompson
# Processing Record 42 of Set 5 | xilin hot
# Processing Record 43 of Set 5 | mugia
# Processing Record 44 of Set 5 | alice springs
# Processing Record 45 of Set 5 | reggane
# Processing Record 46 of Set 5 | balcarce
# Processing Record 47 of Set 5 | pinhao
# Processing Record 48 of Set 5 | dalandzadgad
# Processing Record 49 of Set 5 | hermanus
# Processing Record 0 of Set 6 | gereida
# Processing Record 1 of Set 6 | hassi messaoud
# Processing Record 2 of Set 6 | papao
# Processing Record 3 of Set 6 | daru
# Processing Record 4 of Set 6 | hawaiian paradise park
# Processing Record 5 of Set 6 | abbeville
# Processing Record 6 of Set 6 | birzebbuga
# Processing Record 7 of Set 6 | santa elena de uairen
# Processing Record 8 of Set 6 | sarukhan
# Processing Record 9 of Set 6 | yanam
# Processing Record 10 of Set 6 | tingi
# Processing Record 11 of Set 6 | saint-philippe
# Processing Record 12 of Set 6 | malumfashi
# Processing Record 13 of Set 6 | yuyao
# Processing Record 14 of Set 6 | carnarvon
# Processing Record 15 of Set 6 | akureyri
# Processing Record 16 of Set 6 | nova vicosa
# Processing Record 17 of Set 6 | gudari
# Processing Record 18 of Set 6 | jamaame
# Processing Record 19 of Set 6 | miles city
# Processing Record 20 of Set 6 | nemuro
# Processing Record 21 of Set 6 | kavaratti
# Processing Record 22 of Set 6 | tazacorte
# Processing Record 23 of Set 6 | elko
# Processing Record 24 of Set 6 | boden
# Processing Record 25 of Set 6 | keflavik
# Processing Record 26 of Set 6 | pama
# Processing Record 27 of Set 6 | newport
# Processing Record 28 of Set 6 | mostaganem
# Processing Record 29 of Set 6 | mount gambier
# Processing Record 30 of Set 6 | sungai penuh
# Processing Record 31 of Set 6 | dunedin
# Processing Record 32 of Set 6 | sandviken
# Processing Record 33 of Set 6 | ras gharib
# City not found. Skipping...
# Processing Record 34 of Set 6 | kem'
# Processing Record 35 of Set 6 | ust-nera
# Processing Record 36 of Set 6 | peterborough
# Processing Record 37 of Set 6 | sao vicente
# Processing Record 38 of Set 6 | bikenibeu village
# Processing Record 39 of Set 6 | dakhla
# Processing Record 40 of Set 6 | launceston
# Processing Record 41 of Set 6 | mhamid
# Processing Record 42 of Set 6 | tarawa
# Processing Record 43 of Set 6 | aras-asan
# Processing Record 44 of Set 6 | kingston
# Processing Record 45 of Set 6 | masterton
# Processing Record 46 of Set 6 | gulf shores
# Processing Record 47 of Set 6 | colonia
# Processing Record 48 of Set 6 | ciudad lazaro cardenas
# Processing Record 49 of Set 6 | fandrandava
# Processing Record 0 of Set 7 | crucecita
# Processing Record 1 of Set 7 | chadan
# Processing Record 2 of Set 7 | zemio
# Processing Record 3 of Set 7 | savannah
# Processing Record 4 of Set 7 | ribeira brava
# Processing Record 5 of Set 7 | sao gabriel da cachoeira
# Processing Record 6 of Set 7 | chibougamau
# Processing Record 7 of Set 7 | n'zeto
# Processing Record 8 of Set 7 | paka
# Processing Record 9 of Set 7 | amarpatan
# Processing Record 10 of Set 7 | labrador city
# Processing Record 11 of Set 7 | st. john's
# Processing Record 12 of Set 7 | sao joao da barra
# Processing Record 13 of Set 7 | uturoa
# Processing Record 14 of Set 7 | pimentel
# Processing Record 15 of Set 7 | tancacha
# Processing Record 16 of Set 7 | puerto penasco
# Processing Record 17 of Set 7 | liwale
# Processing Record 18 of Set 7 | escanaba
# Processing Record 19 of Set 7 | kurnool
# Processing Record 20 of Set 7 | sirjan
# Processing Record 21 of Set 7 | tiksi
# Processing Record 22 of Set 7 | karangampel
# Processing Record 23 of Set 7 | callao
# Processing Record 24 of Set 7 | at taj
# Processing Record 25 of Set 7 | zuni pueblo
# Processing Record 26 of Set 7 | west monroe
# Processing Record 27 of Set 7 | newman
# Processing Record 28 of Set 7 | tual
# Processing Record 29 of Set 7 | hithadhoo
# Processing Record 30 of Set 7 | sungai raya
# Processing Record 31 of Set 7 | wanning
# Processing Record 32 of Set 7 | santa ana
# Processing Record 33 of Set 7 | lata
# Processing Record 34 of Set 7 | tamanrasset
# Processing Record 35 of Set 7 | palikir - national government center
# Processing Record 36 of Set 7 | ambazac
# Processing Record 37 of Set 7 | sainyabuli
# Processing Record 38 of Set 7 | acarau
# Processing Record 39 of Set 7 | gaspe
# Processing Record 40 of Set 7 | chake chake
# Processing Record 41 of Set 7 | saudarkrokur
# Processing Record 42 of Set 7 | ikungi
# Processing Record 43 of Set 7 | kochenevo
# Processing Record 44 of Set 7 | muynoq
# Processing Record 45 of Set 7 | catumbela
# Processing Record 46 of Set 7 | haiku-pauwela
# Processing Record 47 of Set 7 | bodo
# Processing Record 48 of Set 7 | mount isa
# Processing Record 49 of Set 7 | motueka
# Processing Record 0 of Set 8 | kristiansund
# Processing Record 1 of Set 8 | gao
# Processing Record 2 of Set 8 | nekrasovka
# Processing Record 3 of Set 8 | new norfolk
# Processing Record 4 of Set 8 | cabo san lucas
# Processing Record 5 of Set 8 | harper
# Processing Record 6 of Set 8 | lagoa formosa
# Processing Record 7 of Set 8 | savave village
# City not found. Skipping...
# Processing Record 8 of Set 8 | san fernando
# Processing Record 9 of Set 8 | union
# Processing Record 10 of Set 8 | diego de almagro
# Processing Record 11 of Set 8 | marataizes
# Processing Record 12 of Set 8 | cimitarra
# Processing Record 13 of Set 8 | namdrik
# Processing Record 14 of Set 8 | xinyang
# Processing Record 15 of Set 8 | eduardo castex
# Processing Record 16 of Set 8 | luderitz
# Processing Record 17 of Set 8 | serchhip
# Processing Record 18 of Set 8 | kiffa
# Processing Record 19 of Set 8 | dezhou
# Processing Record 20 of Set 8 | galveston
# Processing Record 21 of Set 8 | villa huidobro
# Processing Record 22 of Set 8 | fuglafjordur
# Processing Record 23 of Set 8 | i-n-salah
# Processing Record 24 of Set 8 | obidos
# Processing Record 25 of Set 8 | gambela
# Processing Record 26 of Set 8 | boa vista
# Processing Record 27 of Set 8 | kraksaan
# Processing Record 28 of Set 8 | egilsstadir
# Processing Record 29 of Set 8 | treinta y tres
# Processing Record 30 of Set 8 | pandan
# Processing Record 31 of Set 8 | conception bay south
# Processing Record 32 of Set 8 | howrah
# Processing Record 33 of Set 8 | alofi
# Processing Record 34 of Set 8 | longyearbyen
# Processing Record 35 of Set 8 | aykhal
# Processing Record 36 of Set 8 | laojunmiao
# Processing Record 37 of Set 8 | sillamae
# Processing Record 38 of Set 8 | wellington
# Processing Record 39 of Set 8 | burela de cabo
# Processing Record 40 of Set 8 | catacocha
# Processing Record 41 of Set 8 | boguchany
# Processing Record 42 of Set 8 | plouzane
# Processing Record 43 of Set 8 | wamba
# Processing Record 44 of Set 8 | miringa
# Processing Record 45 of Set 8 | mili
# Processing Record 46 of Set 8 | ostersund
# Processing Record 47 of Set 8 | codrington
# Processing Record 48 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 8 | ebeltoft
# Processing Record 0 of Set 9 | la'ie
# Processing Record 1 of Set 9 | meadow lakes
# Processing Record 2 of Set 9 | tazovsky
# Processing Record 3 of Set 9 | pointe aux piments
# Processing Record 4 of Set 9 | aleg
# Processing Record 5 of Set 9 | domoni
# Processing Record 6 of Set 9 | yanta
# Processing Record 7 of Set 9 | korla
# Processing Record 8 of Set 9 | santanyi
# Processing Record 9 of Set 9 | las tablas
# Processing Record 10 of Set 9 | inhambane
# Processing Record 11 of Set 9 | piti village
# Processing Record 12 of Set 9 | pelabuhanratu
# Processing Record 13 of Set 9 | talcahuano
# Processing Record 14 of Set 9 | ayorou
# Processing Record 15 of Set 9 | puerto baquerizo moreno
# Processing Record 16 of Set 9 | uberaba
# Processing Record 17 of Set 9 | porto novo
# Processing Record 18 of Set 9 | mogocha
# Processing Record 19 of Set 9 | labuan lombok
# City not found. Skipping...
# Processing Record 20 of Set 9 | miyaly
# Processing Record 21 of Set 9 | happy valley-goose bay
# Processing Record 22 of Set 9 | richards bay
# Processing Record 23 of Set 9 | mount pearl
# Processing Record 24 of Set 9 | bridlington
# Processing Record 25 of Set 9 | torres
# Processing Record 26 of Set 9 | mermoz boabab
# Processing Record 27 of Set 9 | mando
# Processing Record 28 of Set 9 | borovichi
# Processing Record 29 of Set 9 | maintirano
# Processing Record 30 of Set 9 | general villegas
# Processing Record 31 of Set 9 | kapuskasing
# Processing Record 32 of Set 9 | quesnel
# Processing Record 33 of Set 9 | kolonia town
# Processing Record 34 of Set 9 | ouani
# Processing Record 35 of Set 9 | aldan
# Processing Record 36 of Set 9 | albertina
# Processing Record 37 of Set 9 | mariyenburg
# City not found. Skipping...
# Processing Record 38 of Set 9 | cruzeiro do sul
# Processing Record 39 of Set 9 | tarauaca
# Processing Record 40 of Set 9 | kourou
# Processing Record 41 of Set 9 | kathmandu
# Processing Record 42 of Set 9 | khanty-mansiysk
# Processing Record 43 of Set 9 | kailua-kona
# Processing Record 44 of Set 9 | hadibu
# Processing Record 45 of Set 9 | astrakhan
# Processing Record 46 of Set 9 | mbuji-mayi
# Processing Record 47 of Set 9 | gisborne
# Processing Record 48 of Set 9 | mossel bay
# Processing Record 49 of Set 9 | trairi
# Processing Record 0 of Set 10 | ketchikan
# Processing Record 1 of Set 10 | yorkton
# Processing Record 2 of Set 10 | verkhnevilyuysk
# Processing Record 3 of Set 10 | magangue
# Processing Record 4 of Set 10 | sinabang
# Processing Record 5 of Set 10 | novodvinsk
# Processing Record 6 of Set 10 | doka
# Processing Record 7 of Set 10 | kingscliff
# Processing Record 8 of Set 10 | port hedland
# Processing Record 9 of Set 10 | langsa
# Processing Record 10 of Set 10 | palmer
# Processing Record 11 of Set 10 | saksaul'skiy
# City not found. Skipping...
# Processing Record 12 of Set 10 | sangkhla buri
# Processing Record 13 of Set 10 | sabha
# Processing Record 14 of Set 10 | cannonvale
# Processing Record 15 of Set 10 | villarrica
# Processing Record 16 of Set 10 | carutapera
# Processing Record 17 of Set 10 | pemba
# Processing Record 18 of Set 10 | sikonge
# Processing Record 19 of Set 10 | menemen
# Processing Record 20 of Set 10 | jeddah
# Processing Record 21 of Set 10 | vilhena
# Processing Record 22 of Set 10 | moratuwa
# Processing Record 23 of Set 10 | khuzdar
# Processing Record 24 of Set 10 | manta
# Processing Record 25 of Set 10 | roxas city
# Processing Record 26 of Set 10 | loch garman
# Processing Record 27 of Set 10 | kostomuksha
# Processing Record 28 of Set 10 | nadi
# Processing Record 29 of Set 10 | namtsy
# Processing Record 30 of Set 10 | cascais
# Processing Record 31 of Set 10 | toba
# Processing Record 32 of Set 10 | weno
# Processing Record 33 of Set 10 | rawson
# Processing Record 34 of Set 10 | brisas de zicatela
# Processing Record 35 of Set 10 | antalaha
# Processing Record 36 of Set 10 | nishinoomote
# Processing Record 37 of Set 10 | siwa oasis
# Processing Record 38 of Set 10 | ilheus
# Processing Record 39 of Set 10 | taro
# Processing Record 40 of Set 10 | fale old settlement
# Processing Record 41 of Set 10 | sishilichengzi
# City not found. Skipping...
# Processing Record 42 of Set 10 | lame
# Processing Record 43 of Set 10 | nchelenge
# Processing Record 44 of Set 10 | greenisland
# Processing Record 45 of Set 10 | igarka
# Processing Record 46 of Set 10 | mersing
# Processing Record 47 of Set 10 | kshenskiy
# Processing Record 48 of Set 10 | wuhai
# Processing Record 49 of Set 10 | neftcala
# Processing Record 0 of Set 11 | geraldton
# Processing Record 1 of Set 11 | atar
# Processing Record 2 of Set 11 | jiutai
# Processing Record 3 of Set 11 | nabire
# Processing Record 4 of Set 11 | ta`u
# Processing Record 5 of Set 11 | tromso
# Processing Record 6 of Set 11 | saint croix
# Processing Record 7 of Set 11 | san fernando de apure
# Processing Record 8 of Set 11 | xique xique
# Processing Record 9 of Set 11 | buka
# Processing Record 10 of Set 11 | dawson creek
# Processing Record 11 of Set 11 | tan-tan
# Processing Record 12 of Set 11 | jodhpur
# Processing Record 13 of Set 11 | shimokizukuri
# Processing Record 14 of Set 11 | ulladulla
# Processing Record 15 of Set 11 | namie
# Processing Record 16 of Set 11 | yylanly
# City not found. Skipping...
# Processing Record 17 of Set 11 | la ronge
# Processing Record 18 of Set 11 | angra dos reis
# Processing Record 19 of Set 11 | biga
# Processing Record 20 of Set 11 | grajau
# Processing Record 21 of Set 11 | nar'yan-mar
# Processing Record 22 of Set 11 | krasnoarmeysk
# Processing Record 23 of Set 11 | madimba
# Processing Record 24 of Set 11 | haapajarvi
# Processing Record 25 of Set 11 | tangalle
# Processing Record 26 of Set 11 | sitampiky
# City not found. Skipping...
# Processing Record 27 of Set 11 | suoyarvi
# Processing Record 28 of Set 11 | yengema
# Processing Record 29 of Set 11 | bardai
# Processing Record 30 of Set 11 | huocheng
# City not found. Skipping...
# Processing Record 31 of Set 11 | magdalena
# Processing Record 32 of Set 11 | ibusuki
# Processing Record 33 of Set 11 | ocean shores
# Processing Record 34 of Set 11 | baluntaicun
# City not found. Skipping...
# Processing Record 35 of Set 11 | winkler
# Processing Record 36 of Set 11 | mahdia
# Processing Record 37 of Set 11 | yacuiba
# Processing Record 38 of Set 11 | alingsas
# Processing Record 39 of Set 11 | kendari
# Processing Record 40 of Set 11 | urangan
# Processing Record 41 of Set 11 | zhezqazghan
# Processing Record 42 of Set 11 | cadale
# Processing Record 43 of Set 11 | merritt
# Processing Record 44 of Set 11 | solnechnyy
# Processing Record 45 of Set 11 | bulgan
# Processing Record 46 of Set 11 | portel
# Processing Record 47 of Set 11 | filey
# Processing Record 48 of Set 11 | aldinga beach
# Processing Record 49 of Set 11 | as sulayyil
# Processing Record 0 of Set 12 | ibirama
# Processing Record 1 of Set 12 | miyako
# Processing Record 2 of Set 12 | bubaque
# Processing Record 3 of Set 12 | horta
# Processing Record 4 of Set 12 | zhaotong
# Processing Record 5 of Set 12 | parabel'
# Processing Record 6 of Set 12 | quibdo
# Processing Record 7 of Set 12 | hotan
# Processing Record 8 of Set 12 | xining
# Processing Record 9 of Set 12 | kapa'a
# Processing Record 10 of Set 12 | kruisfontein
# Processing Record 11 of Set 12 | takamaka
# City not found. Skipping...
# Processing Record 12 of Set 12 | sola
# Processing Record 13 of Set 12 | jalai nur
# Processing Record 14 of Set 12 | katabu
# Processing Record 15 of Set 12 | aizawl
# Processing Record 16 of Set 12 | rio branco
# Processing Record 17 of Set 12 | al 'alamayn
# City not found. Skipping...
# Processing Record 18 of Set 12 | jurbarkas
# Processing Record 19 of Set 12 | mae hong son
# Processing Record 20 of Set 12 | soio
# Processing Record 21 of Set 12 | kununurra
# Processing Record 22 of Set 12 | mokhsogollokh
# Processing Record 23 of Set 12 | beipiao
# Processing Record 24 of Set 12 | bayanaul
# Processing Record 25 of Set 12 | tolanaro
# Processing Record 26 of Set 12 | undurkhaan
# Processing Record 27 of Set 12 | sangmelima
# Processing Record 28 of Set 12 | saint-francois
# Processing Record 29 of Set 12 | motygino
# Processing Record 30 of Set 12 | opuwo
# Processing Record 31 of Set 12 | walvis bay
# Processing Record 32 of Set 12 | marsa alam
# Processing Record 33 of Set 12 | patacamaya
# Processing Record 34 of Set 12 | shiguai
# -----------------------------
# Data Retrieval Complete

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          553
# Lat           553
# Lng           553
# Max Temp      553
# Humidity      553
# Cloudiness    553
# Wind Speed    553
# Country       553
# Date          553
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  fort mcmurray  56.7268 -111.3810     23.77        40         100
# 1         olinda  -8.0089  -34.8553     25.85        83          75
# 2        college  64.8569 -147.8028     20.05        39          40
# 3          ancud -41.8697  -73.8203      7.16        90         100
# 4     bredasdorp -34.5322   20.0403     11.10        65         100
#
#    Wind Speed Country        Date
# 0        3.09      CA  1684705377
# 1        2.57      BR  1684705378
# 2        2.57      US  1684705188
# 3        1.50      CL  1684705379
# 4        1.75      ZA  1684705379

# %%
import os

# Create the output_data directory if it doesn't exist
output_dir = "output_data"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        fort mcmurray  56.7268 -111.3810     23.77        40         100
# 1               olinda  -8.0089  -34.8553     25.85        83          75
# 2              college  64.8569 -147.8028     20.05        39          40
# 3                ancud -41.8697  -73.8203      7.16        90         100
# 4           bredasdorp -34.5322   20.0403     11.10        65         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.09      CA  1684705377
# 1              2.57      BR  1684705378
# 2              2.57      US  1684705188
# 3              1.50      CL  1684705379
# 4              1.75      ZA  1684705379

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Incorporate the other graph properties
plt.title('City Latitude vs. Max Temperature (%s)' % time.strftime("%Y-%m-%d"))
plt.grid(True)


# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE



# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
plt.title('Latitude vs. Humidity (%s)' % time.strftime("%Y-%m-%d"))
plt.grid(True)


# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
plt.title('City Latitude vs. Cloudiness (%s)' % time.strftime("%Y-%m-%d"))
plt.grid(True)

# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('latitude')
plt.ylabel('Cloudiness(%)')
plt.show()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.title('City Latitude vs. Wind Speed (%s)' % time.strftime("%Y-%m-%d"))
plt.grid(True)

# Incorporate the other graph properties
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)
plt.xlabel('latitude')
plt.ylabel('Wind Speed(m/s)')
plt.show()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0               fort mcmurray  56.7268 -111.3810     23.77        40
# 2                     college  64.8569 -147.8028     20.05        39
# 6                 bang saphan  11.2126   99.5117     25.84        84
# 7        nikolayevsk-on-amure  53.1406  140.7300      6.24        84
# 9                  gadzhiyevo  69.2551   33.3362      7.50        93
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.09      CA  1684705377
# 2                40        2.57      US  1684705188
# 6                99        2.84      TH  1684705380
# 7               100        2.00      RU  1684705380
# 9               100        6.14      RU  1684705381

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"]  < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                   olinda  -8.0089  -34.8553     25.85        83          75
# 3                    ancud -41.8697  -73.8203      7.16        90         100
# 4               bredasdorp -34.5322   20.0403     11.10        65         100
# 5        port-aux-francais -49.3500   70.2167      6.62        89          92
# 8                   avarua -21.2078 -159.7750     26.03        78          40
#
#          Wind Speed Country        Date
# City_ID
# 1              2.57      BR  1684705378
# 3              1.50      CL  1684705379
# 4              1.75      ZA  1684705379
# 5             13.59      TF  1684705380
# 8              4.63      CK  1684705381

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
from scipy.stats import linregress
import matplotlib.pyplot as plt
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df ['Lat'] 
y_values = northern_hemi_df ['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#create_linear_regression_plot(x_values, y_values, "Latitude", "Max Temperature", "Northern")
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

plt.xlabel('Latitude ')
plt.ylabel('Max temp')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.6498863181268784

# %%
#Discussion about the linear relationship: Overall, an r-squared value of 0.6499 indicates a moderate positive correlation between 
#latitude and maximum temperature in the Northern Hemisphere.

# %%
# Linear regression on Southern Hemisphere
from scipy.stats import linregress
import matplotlib.pyplot as plt

# Linear regression on Northern Hemisphere
x_values = southern_hemi_df ['Lat'] 
y_values = southern_hemi_df ['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#create_linear_regression_plot(x_values, y_values, "Latitude", "Max Temperature", "Northern")
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")

plt.xlabel('Latitude ')
plt.ylabel('Max temp')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.6530277813413345

# %%
#Discussion about the linear relationship: Since the R-squared value ranges from 0 to 1, a value of 0.653 suggests a moderate 
#level of correlation between Latitude and Max Temperature in the Southern Hemisphere. 
#This means that there is a tendency for Max Temperature to decrease as 
#Latitude moves towards the South

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Linear regression on Northern Hemisphere
x_values = northern_hemi_df ['Lat'] 
y_values = northern_hemi_df ['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#create_linear_regression_plot(x_values, y_values, "Latitude", "Max Temperature", "Northern")
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0.1,50),fontsize=15,color="red")

plt.xlabel('Latitude ')
plt.ylabel('Humidity')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.004645764612872593

# %%
# Discussion about the linear relationship:The r-squared value of 0.004645764612872593 indicates a 
very weak correlation between the variables being compared

# %%
# Southern Hemisphere

# Linear regression on Northern Hemisphere
x_values = southern_hemi_df ['Lat'] 
y_values = southern_hemi_df ['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#create_linear_regression_plot(x_values, y_values, "Latitude", "Max Temperature", "Northern")
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,30),fontsize=15,color="red")

plt.xlabel('Latitude ')
plt.ylabel('Humidity')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.00963787832857903

# %%
# Discussion about the linear relationship: The r-squared value of 0.00963787832857903 indicates a very weak correlation

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df ['Lat'] 
y_values = northern_hemi_df ['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#create_linear_regression_plot(x_values, y_values, "Latitude", "Max Temperature", "Northern")
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")

plt.xlabel('Latitude ')
plt.ylabel('Cloudiness')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.00024307681825659521

# %%
# Southern Hemisphere
# Linear regression on Northern Hemisphere
x_values = southern_hemi_df ['Lat'] 
y_values = southern_hemi_df ['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#create_linear_regression_plot(x_values, y_values, "Latitude", "Max Temperature", "Northern")
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,30),fontsize=15,color="red")

plt.xlabel('Latitude ')
plt.ylabel('Cloudiness')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.03847697639686053

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df ['Lat'] 
y_values = northern_hemi_df ['Wind']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#create_linear_regression_plot(x_values, y_values, "Latitude", "Max Temperature", "Northern")
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")

plt.xlabel('Latitude ')
plt.ylabel('Wind')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# Linear regression on Northern Hemisphere
x_values = southern_hemi_df ['Lat'] 
y_values = southern_hemi_df ['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#create_linear_regression_plot(x_values, y_values, "Latitude", "Max Temperature", "Northern")
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")

plt.xlabel('Latitude ')
plt.ylabel('Wind Speed')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.02477699140327353

# %%
# Discussion about the linear relationship:
#The r-squared value of 0.02477699140327353 for the relationship between latitude and wind speed
#in the Southern Hemisphere indicates a very weak correlation

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
